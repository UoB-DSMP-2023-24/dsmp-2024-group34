# %% [markdown]
# ## Sorting Data into spending sectors (Cafe, pub etc.)

# %%
import pandas as pd
import numpy as np

# %%
transaction_df = pd.read_csv('C:/Users/camer/OneDrive/Documents/Data Science MSc/DSMP/fake_transactional_data_24.csv')
transaction_df.head()
# Out:
#    from_totally_fake_account  monopoly_money_amount  \
# 0                    10371.0                   4.00
# 1                    88339.0                   2.40
# 2                    18555.0                   2.40
# 3                    18555.0                   4.10
# 4                    80792.0                   1.95
#
#   to_randomly_generated_account not_happened_yet_date
# 0                        CINEMA            01/01/2025
# 1                         40544            01/01/2025
# 2                         85149            01/01/2025
# 3           HIPSTER_COFFEE_SHOP            01/01/2025
# 4                         18555            01/01/2025

# %% [markdown]
# #### Preparing the data - sorting by reciever account

# %% [markdown]
# Many of the transcations are to personal accounts, these can be removed. The other buisness accounts can then be grouped into sectors to be able to cluster based on where people spend their money.

# %% [markdown]
# Getting a list of the non-numeric receiver account transactions in the data

# %%
unique_values = transaction_df['to_randomly_generated_account'].unique()

buisness_accounts = []

for value in unique_values:
    if str(value).isdigit() == False:
        buisness_accounts.append(value)

# %%
#buisness_accounts

# %% [markdown]
# Sorting list of buisnesses into categories (small enough number to do manually)

# %%
categories = {
    'Coffee Shop': ['COFFEE_SHOP', 'HIPSTER_COFFEE_SHOP', 'TOTALLY_A_REAL_COFFEE_SHOP', 'A_CAFE', 'GOURMET_COFFEE_SHOP', 'A_LOCAL_COFFEE_SHOP', 'WE_HAVE_BEAN_WEIGHTING', 'PRETENTIOUS_COFFEE_SHOP', 'CAFE', 'TO_BEAN_OR_NOT_TO_BEAN'],
    'Eating Out': ['LUNCH_PLACE', 'RESTAURANT', 'LOCAL_RESTAURANT', 'INDIAN_RESTAURANT', 'SEAFOOD_RESAURANT', 'STEAK_HOUSE', 'CHINESE_RESTAURANT', 'TAKEAWAY_CURRY', 'TAKEAWAY', 'ROASTERIE', 'RESTAURANT_VOUCHER', 'CHINESE_TAKEAWAY', 'TAKEAWAY', 'LUNCH_VAN', 'KEBAB_SHOP', 'SANDWICH_SHOP'],
    'Bar/Pub': ['LOCAL_WATERING_HOLE', 'LOCAL_PUB', 'BAR', 'PUB', 'WINE_BAR', 'WHISKEY_BAR', 'COCKTAIL_BAR', 'G&T_BAR', 'WINE_CELLAR'],
    'Supermarket': ['LARGE_SUPERMARKET', 'EXPRESS_SUPERMARKET', 'A_SUPERMARKET', 'THE_SUPERMARKET'],
    'Alcohol': ['LIQUOR_STORE', 'WHISKEY_SHOP'],
    'Books': ['COMIC_BOOK_SHOP', 'LOCAL_BOOKSHOP', 'SECOND_HAND_BOOKSHOP', 'NERDY_BOOK_STORE', 'BOOKSHOP'],
    'Electronics': ['ELECTRONICS_SHOP', 'HIPSTER_ELECTRONICS_SHOP', 'TECH_SHOP'],
    'Clothing': ['FASHION_SHOP', 'FASHIONABLE_SPORTSWARE_SHOP', 'CLOTHES_SHOP', 'JEWLLERY_SHOP', 'ACCESSORY_SHOP'],
    'Children': ['TOY_SHOP', 'CHILDRENDS_SHOP', 'KIDS_ACTIVITY_CENTRE', 'SCHOOL_SUPPLY_STORE', 'KIDS_CLOTHING_SHOP'],
    'Exercise': ['TRAINER_SHOP', 'SPORT_SHOP', 'RUNNING_SHOP', 'GYM'],
    'Pet': ['PET_TOY_SHOP', 'PET_SHOP'],
    'High Street': ['TEA_SHOP', 'COOKSHOP', 'FLORIST', 'BUTCHERS', 'BUTCHER', 'TURKEY_FARM', 'GREENGROCER'],
    'Home': ['DIY_STORE', 'HOME_IMPROVEMENT_STORE', 'DEPARTMENT_STORE'],
    'Entertainment':['VIDEO_GAME_STORE','STREAMING_SERVICE', 'CINEMA', 'DVD_SHOP', 'GAME_SHOP'],
}

# %% [markdown]
# Removing the personal account recievers (numeric) from the data

# %%
buisness_transactions = transaction_df[~transaction_df['to_randomly_generated_account'].str.isdigit()]

# %%
buisness_transactions
# Out:
#           from_totally_fake_account  monopoly_money_amount  \
# 0                           10371.0                   4.00
# 3                           18555.0                   4.10
# 5                           18555.0                   4.45
# 6                           18555.0                   1.45
# 7                           18555.0                   5.00
# ...                             ...                    ...
# 10148274                    81404.0                   1.80
# 10148275                    32185.0                   2.65
# 10148276                    32185.0                   2.45
# 10148277                    57569.0                  14.00
# 10148279                    53444.0                   2.65
#
#          to_randomly_generated_account not_happened_yet_date
# 0                               CINEMA            01/01/2025
# 3                  HIPSTER_COFFEE_SHOP            01/01/2025
# 5           TOTALLY_A_REAL_COFFEE_SHOP            01/01/2025
# 6                          COFFEE_SHOP            01/01/2025
# 7                                 CAFE            01/01/2025
# ...                                ...                   ...
# 10148274    TOTALLY_A_REAL_COFFEE_SHOP            31/12/2025
# 10148275                   COFFEE_SHOP            31/12/2025
# 10148276                   COFFEE_SHOP            31/12/2025
# 10148277                      WINE_BAR            31/12/2025
# 10148279           A_LOCAL_COFFEE_SHOP            31/12/2025
#
# [7615517 rows x 4 columns]

# %% [markdown]
# Calculating the spending of each account in each catergory

# %%
buisness_transactions['category'] = 'None'

for category, keywords in categories.items():
    buisness_transactions.loc[buisness_transactions['to_randomly_generated_account'].isin(keywords), 'category'] = category

buisness_transactions
# Out:
# C:\Users\camer\AppData\Local\Temp\ipykernel_3316\895442682.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   buisness_transactions['category'] = 'None'
#           from_totally_fake_account  monopoly_money_amount  \
# 0                           10371.0                   4.00
# 3                           18555.0                   4.10
# 5                           18555.0                   4.45
# 6                           18555.0                   1.45
# 7                           18555.0                   5.00
# ...                             ...                    ...
# 10148274                    81404.0                   1.80
# 10148275                    32185.0                   2.65
# 10148276                    32185.0                   2.45
# 10148277                    57569.0                  14.00
# 10148279                    53444.0                   2.65
#
#          to_randomly_generated_account not_happened_yet_date       category
# 0                               CINEMA            01/01/2025  Entertainment
# 3                  HIPSTER_COFFEE_SHOP            01/01/2025    Coffee Shop
# 5           TOTALLY_A_REAL_COFFEE_SHOP            01/01/2025    Coffee Shop
# 6                          COFFEE_SHOP            01/01/2025    Coffee Shop
# 7                                 CAFE            01/01/2025    Coffee Shop
# ...                                ...                   ...            ...
# 10148274    TOTALLY_A_REAL_COFFEE_SHOP            31/12/2025    Coffee Shop
# 10148275                   COFFEE_SHOP            31/12/2025    Coffee Shop
# 10148276                   COFFEE_SHOP            31/12/2025    Coffee Shop
# 10148277                      WINE_BAR            31/12/2025        Bar/Pub
# 10148279           A_LOCAL_COFFEE_SHOP            31/12/2025    Coffee Shop
#
# [7615517 rows x 5 columns]

# %% [markdown]
# Pivoting the data to have the categories as columns

# %%
sender_category_spending = buisness_transactions.groupby(['from_totally_fake_account', 'category'])['monopoly_money_amount'].sum().reset_index()

# %%
pivoted_data = sender_category_spending.pivot(index='from_totally_fake_account', columns='category', values='monopoly_money_amount').reset_index()

pivoted_data = pivoted_data.fillna(0)

pivoted_data
# Out:
# category  from_totally_fake_account  Alcohol  Bar/Pub  Books  Children  \
# 0                            1000.0    10.00  4716.88    8.0     160.0
# 1                            1002.0    49.99  4564.45    0.0     268.0
# 2                            1006.0    57.96  4234.29  412.0    1480.0
# 3                            1018.0    29.99  2533.50   20.0      59.0
# 4                            1053.0   104.98  3950.20    0.0     133.0
# ...                             ...      ...      ...    ...       ...
# 8137                       100931.0   249.96  5660.57  353.0     175.0
# 8138                       100934.0    93.98  4414.10  518.0       0.0
# 8139                       100947.0    69.97  4927.28  503.0     120.0
# 8140                       100986.0    63.97  4926.11   35.0       0.0
# 8141                       100988.0   187.94  4779.27   20.0    1695.0
#
# category  Clothing  Coffee Shop  Eating Out  Electronics  Entertainment  \
# 0            145.0      2023.38     1706.39          0.0         411.88
# 1             62.0       525.11     1537.17          0.0         969.88
# 2             65.0      2075.95     1623.16          0.0         696.88
# 3           2093.0        46.69     1871.36          0.0         135.00
# 4           2676.0       819.48     2668.82         79.0         675.88
# ...            ...          ...         ...          ...            ...
# 8137         313.0       715.42     1451.40        170.0        1281.88
# 8138         195.0       614.81     1532.33          0.0         292.88
# 8139         131.0       779.82     2728.58        276.0         465.88
# 8140         678.0        80.55     1792.84          0.0         441.88
# 8141        1977.0       747.17     2386.77          0.0          91.00
#
# category  Exercise  High Street    Home    Pet  Supermarket
# 0              0.0         0.00    93.0  529.0       681.93
# 1            113.0        20.46     0.0    0.0      1045.61
# 2              0.0      3095.05    44.0    0.0       931.20
# 3              0.0      1978.75  1219.0   30.0      1288.22
# 4              0.0        65.64   847.0    0.0      1119.22
# ...            ...          ...     ...    ...          ...
# 8137        1617.0      2445.97     0.0    0.0      1086.86
# 8138           0.0        19.64   115.0    0.0      5716.51
# 8139          90.0        96.36    98.0    0.0      5700.33
# 8140         766.0         5.00     0.0   10.0      3863.01
# 8141           0.0       125.00   926.0    0.0      1366.12
#
# [8142 rows x 15 columns]

# %%
categorical_spending_by_account = pivoted_data

# %% [markdown]
# Checking data for one account

# %%
acc_1006 = buisness_transactions[buisness_transactions['from_totally_fake_account'] == 1006]

# %%
acc_1006[acc_1006['category'] == 'Alcohol']
# Out:
#          from_totally_fake_account  monopoly_money_amount  \
# 1450947                     1006.0                  19.99
# 7379165                     1006.0                   8.99
# 7927000                     1006.0                   8.99
# 8826268                     1006.0                  19.99
#
#         to_randomly_generated_account not_happened_yet_date category
# 1450947                  WHISKEY_SHOP            22/02/2025  Alcohol
# 7379165                  LIQUOR_STORE            26/09/2025  Alcohol
# 7927000                  WHISKEY_SHOP            15/10/2025  Alcohol
# 8826268                  LIQUOR_STORE            16/11/2025  Alcohol

# %% [markdown]
# Sum of alcohol for 1006 should be 57.96

# %%
categorical_spending_by_account[categorical_spending_by_account['from_totally_fake_account'] == 1006]['Alcohol']
# Out:
# 2    57.96
# Name: Alcohol, dtype: float64

# %% [markdown]
# Saving categorical data to csv

# %%
categorical_spending_by_account.to_csv('Categorical_spending_by_account.csv', index=False)

# %% [markdown]
# Finding the proportion of the total money spent by each account in each category

# %%
categories_only = categorical_spending_by_account.drop('from_totally_fake_account', axis=1)
total_spending_per_account = categories_only.sum(axis=1)
categorical_spending_by_account['total_spending'] = total_spending_per_account

# %%
categorical_spending_by_account
# Out:
# category  from_totally_fake_account  Alcohol  Bar/Pub  Books  Children  \
# 0                            1000.0    10.00  4716.88    8.0     160.0
# 1                            1002.0    49.99  4564.45    0.0     268.0
# 2                            1006.0    57.96  4234.29  412.0    1480.0
# 3                            1018.0    29.99  2533.50   20.0      59.0
# 4                            1053.0   104.98  3950.20    0.0     133.0
# ...                             ...      ...      ...    ...       ...
# 8137                       100931.0   249.96  5660.57  353.0     175.0
# 8138                       100934.0    93.98  4414.10  518.0       0.0
# 8139                       100947.0    69.97  4927.28  503.0     120.0
# 8140                       100986.0    63.97  4926.11   35.0       0.0
# 8141                       100988.0   187.94  4779.27   20.0    1695.0
#
# category  Clothing  Coffee Shop  Eating Out  Electronics  Entertainment  \
# 0            145.0      2023.38     1706.39          0.0         411.88
# 1             62.0       525.11     1537.17          0.0         969.88
# 2             65.0      2075.95     1623.16          0.0         696.88
# 3           2093.0        46.69     1871.36          0.0         135.00
# 4           2676.0       819.48     2668.82         79.0         675.88
# ...            ...          ...         ...          ...            ...
# 8137         313.0       715.42     1451.40        170.0        1281.88
# 8138         195.0       614.81     1532.33          0.0         292.88
# 8139         131.0       779.82     2728.58        276.0         465.88
# 8140         678.0        80.55     1792.84          0.0         441.88
# 8141        1977.0       747.17     2386.77          0.0          91.00
#
# category  Exercise  High Street    Home    Pet  Supermarket  total_spending
# 0              0.0         0.00    93.0  529.0       681.93        10485.46
# 1            113.0        20.46     0.0    0.0      1045.61         9155.67
# 2              0.0      3095.05    44.0    0.0       931.20        14715.49
# 3              0.0      1978.75  1219.0   30.0      1288.22        11304.51
# 4              0.0        65.64   847.0    0.0      1119.22        13139.22
# ...            ...          ...     ...    ...          ...             ...
# 8137        1617.0      2445.97     0.0    0.0      1086.86        15520.06
# 8138           0.0        19.64   115.0    0.0      5716.51        13512.25
# 8139          90.0        96.36    98.0    0.0      5700.33        15986.22
# 8140         766.0         5.00     0.0   10.0      3863.01        12662.36
# 8141           0.0       125.00   926.0    0.0      1366.12        14301.27
#
# [8142 rows x 16 columns]

# %%
proportion_category_spending = categorical_spending_by_account.iloc[:, 1:15].div(categorical_spending_by_account['total_spending'], axis=0)

# %%
proportion_category_spending
# Out:
# category   Alcohol   Bar/Pub     Books  Children  Clothing  Coffee Shop  \
# 0         0.000954  0.449850  0.000763  0.015259  0.013829     0.192970
# 1         0.005460  0.498538  0.000000  0.029271  0.006772     0.057354
# 2         0.003939  0.287744  0.027998  0.100574  0.004417     0.141072
# 3         0.002653  0.224114  0.001769  0.005219  0.185147     0.004130
# 4         0.007990  0.300642  0.000000  0.010122  0.203665     0.062369
# ...            ...       ...       ...       ...       ...          ...
# 8137      0.016106  0.364726  0.022745  0.011276  0.020167     0.046096
# 8138      0.006955  0.326674  0.038336  0.000000  0.014431     0.045500
# 8139      0.004377  0.308220  0.031465  0.007506  0.008195     0.048781
# 8140      0.005052  0.389036  0.002764  0.000000  0.053545     0.006361
# 8141      0.013141  0.334185  0.001398  0.118521  0.138239     0.052245
#
# category  Eating Out  Electronics  Entertainment  Exercise  High Street  \
# 0           0.162739     0.000000       0.039281  0.000000     0.000000
# 1           0.167893     0.000000       0.105932  0.012342     0.002235
# 2           0.110303     0.000000       0.047357  0.000000     0.210326
# 3           0.165541     0.000000       0.011942  0.000000     0.175041
# 4           0.203119     0.006013       0.051440  0.000000     0.004996
# ...              ...          ...            ...       ...          ...
# 8137        0.093518     0.010954       0.082595  0.104188     0.157601
# 8138        0.113403     0.000000       0.021675  0.000000     0.001453
# 8139        0.170683     0.017265       0.029143  0.005630     0.006028
# 8140        0.141588     0.000000       0.034897  0.060494     0.000395
# 8141        0.166892     0.000000       0.006363  0.000000     0.008740
#
# category      Home       Pet  Supermarket
# 0         0.008869  0.050451     0.065036
# 1         0.000000  0.000000     0.114204
# 2         0.002990  0.000000     0.063280
# 3         0.107833  0.002654     0.113956
# 4         0.064463  0.000000     0.085182
# ...            ...       ...          ...
# 8137      0.000000  0.000000     0.070029
# 8138      0.008511  0.000000     0.423061
# 8139      0.006130  0.000000     0.356578
# 8140      0.000000  0.000790     0.305078
# 8141      0.064749  0.000000     0.095524
#
# [8142 rows x 14 columns]

# %% [markdown]
# Finding the average spending proportions per category and then calculating the over/under spending of each account in each category. This means the categories will be standardised (if average spending in Pub/Bar is 35%, it may dominate a model and therrefore reduce insights into smaller categories)

# %%
average_spending_per_category = proportion_category_spending.mean()

# %%
average_spending_per_category
# Out:
# category
# Alcohol          0.004557
# Bar/Pub          0.334692
# Books            0.014562
# Children         0.041388
# Clothing         0.052308
# Coffee Shop      0.068043
# Eating Out       0.147646
# Electronics      0.007146
# Entertainment    0.026818
# Exercise         0.009759
# High Street      0.051889
# Home             0.030313
# Pet              0.003582
# Supermarket      0.207298
# dtype: float64

# %%
over_under_spending = proportion_category_spending.sub(average_spending_per_category, axis=1)

# %%
over_under_spending.insert(0, 'Sender account', pivoted_data['from_totally_fake_account'])

# %%
over_under_spending
# Out:
# category  Sender account   Alcohol   Bar/Pub     Books  Children  Clothing  \
# 0                 1000.0 -0.003603  0.115157 -0.013799 -0.026129 -0.038480
# 1                 1002.0  0.000903  0.163846 -0.014562 -0.012116 -0.045537
# 2                 1006.0 -0.000618 -0.046949  0.013436  0.059187 -0.047891
# 3                 1018.0 -0.001904 -0.110578 -0.012793 -0.036169  0.132839
# 4                 1053.0  0.003433 -0.034050 -0.014562 -0.031265  0.151357
# ...                  ...       ...       ...       ...       ...       ...
# 8137            100931.0  0.011549  0.030034  0.008183 -0.030112 -0.032141
# 8138            100934.0  0.002399 -0.008018  0.023774 -0.041388 -0.037877
# 8139            100947.0 -0.000180 -0.026472  0.016903 -0.033881 -0.044114
# 8140            100986.0  0.000495  0.054343 -0.011798 -0.041388  0.001236
# 8141            100988.0  0.008585 -0.000507 -0.013163  0.077133  0.085931
#
# category  Coffee Shop  Eating Out  Electronics  Entertainment  Exercise  \
# 0            0.124927    0.015093    -0.007146       0.012463 -0.009759
# 1           -0.010689    0.020247    -0.007146       0.079114  0.002583
# 2            0.073030   -0.037343    -0.007146       0.020539 -0.009759
# 3           -0.063913    0.017895    -0.007146      -0.014876 -0.009759
# 4           -0.005674    0.055473    -0.001133       0.024622 -0.009759
# ...               ...         ...          ...            ...       ...
# 8137        -0.021946   -0.054128     0.003808       0.055777  0.094429
# 8138        -0.022543   -0.034243    -0.007146      -0.005143 -0.009759
# 8139        -0.019262    0.023038     0.010119       0.002325 -0.004129
# 8140        -0.061682   -0.006057    -0.007146       0.008079  0.050735
# 8141        -0.015798    0.019247    -0.007146      -0.020455 -0.009759
#
# category  High Street      Home       Pet  Supermarket
# 0           -0.051889 -0.021443  0.046869    -0.142262
# 1           -0.049655 -0.030313 -0.003582    -0.093094
# 2            0.158437 -0.027322 -0.003582    -0.144018
# 3            0.123151  0.077521 -0.000928    -0.093342
# 4           -0.046894  0.034151 -0.003582    -0.122116
# ...               ...       ...       ...          ...
# 8137         0.105711 -0.030313 -0.003582    -0.137269
# 8138        -0.050436 -0.021802 -0.003582     0.215763
# 8139        -0.045862 -0.024182 -0.003582     0.149280
# 8140        -0.051495 -0.030313 -0.002792     0.097780
# 8141        -0.043149  0.034437 -0.003582    -0.111774
#
# [8142 rows x 15 columns]

# %%
over_under_spending.to_csv('Proportional_spending_by_account.csv', index=False)
